# %% [markdown]
# <a href="https://colab.research.google.com/github/atroug/analysis/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr=np.array([1,2,3])

# %%
print(arr)
# Out:
# [1 2 3]

# %%
print(arr.mean())
# Out:
# 2.0

# %%
import pandas as pd

# %%
df=pd.DataFrame({'A':[1,2],'B':[3,4]})

# %%
print(df)
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
print("\n  وصف احصائ للبيانات:")
# Out:
#   وصف احصائ للبيانات:

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    A  B
# 0  1  3
# 1  2  4>
